# %%
# import matplotlib
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv("C:/Users/USER/Desktop/Simulation/WorkersGradesAtArrivalTask.csv").replace({np.nan:0})

df=df.set_index(df.columns[0])
df=df[df.columns[:-1]]
if len(df)>1000:
    df=df[:-1000]

df.plot(figsize=[20,10])

# %%
df=pd.read_csv("C:/Users/USER/Desktop/Simulation/AvgQueueLength.csv").replace({np.nan:0})

df.plot.scatter(df.columns[0],df.columns[1], xticks=range(1,len(df)+1))

# %%
df=pd.read_csv("C:/Users/USER/Desktop/Simulation/WorkersQueueAtTime.csv")
df=df.set_index(df.columns[0])

for i in range(0,len(df),2):
    tmp=df[i:i+2]  
    tmp=tmp.T
    tmp=tmp.set_index(tmp.columns[0])
    tmp.plot(figsize=[20,10])

# %%
df=pd.read_csv("C:/Users/USER/Desktop/Simulation/WorkersUtilization.csv").replace({np.nan:0})

df.plot.scatter(df.columns[0],df.columns[1], xticks=range(1,len(df)+1))

# %%
df=pd.read_csv("C:/Users/USER/Desktop/Simulation/WorkersBusyAtTime.csv")
df=df.set_index(df.columns[0])

for i in range(0,len(df),2):
    tmp=df[i:i+2]  
    tmp=tmp.T
    tmp=tmp.set_index(tmp.columns[0])
    tmp.plot(figsize=[20,10])

# %%
df=pd.read_csv("C:/Users/USER/Desktop/Simulation/AvgTasksProcessingTime.csv").replace({np.nan:0})

df.plot.scatter(df.columns[0],df.columns[1], xticks=range(1,len(df)+1))

# %%
df=pd.read_csv("C:/Users/USER/Desktop/Simulation/TasksProcessingTime.csv")
df=df.set_index(df.columns[0])

for i in range(0,len(df),2):
    tmp=df[i:i+2]  
    tmp=tmp.T
    
    tmp.plot.scatter(tmp.columns[0],tmp.columns[1],figsize=[20,10])

# %%
df=pd.read_csv("C:/Users/USER/Desktop/Simulation/AvgTasksWaitingTimePerWorker.csv").replace({np.nan:0})

df.plot.scatter(df.columns[0],df.columns[1], xticks=range(1,len(df)+1))

# %%
df=pd.read_csv("C:/Users/USER/Desktop/Simulation/TasksWaitingTime.csv")
df=df.set_index(df.columns[0])

for i in range(0,len(df),2):
    tmp=df[i:i+2]  
    tmp=tmp.T
    
    tmp.plot.scatter(tmp.columns[0],tmp.columns[1],figsize=[20,10])

# %%
df=pd.read_csv("C:/Users/USER/Desktop/Simulation/SumOfWorkerFinishedTsks.csv").replace({np.nan:0})
df=df.set_index(df.columns[0])

df.plot(xticks=range(1,len(df)+1))
